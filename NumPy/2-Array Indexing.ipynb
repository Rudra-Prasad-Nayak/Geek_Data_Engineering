# %%
import numpy as np

# %%
arr = np.arange(11,21)
arr

# %%
arr_slice = arr[3::2]
arr_slice

# %%
arr[4]

# %%
arr = np.arange(1,31).reshape(6,5)
arr

# %%
slice = arr[3:,3:]
slice

# %%
arr[:,2]

# %%
arr = np.arange(11,21)
arr

# %%
bool_index = arr%2 == 0
bool_index

# %%
arr = arr[bool_index]
arr
