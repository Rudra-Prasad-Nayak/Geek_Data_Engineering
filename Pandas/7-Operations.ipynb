# %%
import numpy as np 
import pandas as pd

# %%
df1 = pd.DataFrame({
    'A': [1, 2, 3, 4, 5],
    'B': [10, 20, 30, 40, 50],
    'C': [100, 200, 300, 400, 500]
})
df1

# %%
df1.shape

# %%
df1.columns

# %%
df1.info()

# %%
df1.describe()

# %%
df1['A'] + 10

# %%
df1

# %%
def square(x):
    return x **2

# %%
df1['D'] = df1["B"].apply(square)
df1

# %%
df1['D'] = df1["B"].apply(lambda x : x**2)
df1
