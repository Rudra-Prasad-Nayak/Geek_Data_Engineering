# %%
import numpy as np 
import pandas as pd

# %%
data = {
    'A': [1, 2, np.nan, 4, 5],
    'B': [1, 2, 3, 4, 5],
    'C': [1, 2, 3, np.nan, np.nan],
    'D': [1, np.nan, np.nan, np.nan, 5]
}
df = pd.DataFrame(data)
df

# %%
df.isna()

# %%
df.isna().sum()

# %%
df.isna().any()

# %%
df

# %%
df.dropna()

# %%
df

# %%
# At least 1 Not Null value present and remove others
df.dropna(thresh=1)

# %%
df

# %%
df.fillna(0)

# %%
values = {'A':0,'B':100,"C":300,'D':400}
df.fillna(value=values)

# %%
df

# %%
df.fillna(df.mean())
