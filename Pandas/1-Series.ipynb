# %%
import numpy as np 
import pandas as pd

# %%
my_list = [10, 20, 30]
pd.Series(my_list)

# %%
labels = ['a', 'b', 'c']
pd.Series(my_list, index = labels)

# %%
arr = np.array([10, 20, 30])
pd.Series(arr)

# %%
d = {'a':10, 'b':20, 'c':30}
pd.Series(d)
