# %%
x = 50
x

# %%
y = "Learntek"
y

# %%
x, y, z = 'Hi', 20, 50.5
x
y
z

# %%
x, y, z

# %%
type(x), type(y), type(z)

# %%
A = 23+65j
A, type(A)

# %%
A = """multiline string"""
A

# %%
B = 'Rudra Prasad Nayak'
B[-5:-2]

# %%
B.split(' ')

# %%
B[::-1]

# %%
k = ' Hello World '
k.strip(), k.lstrip(), k.rstrip()

# %%
# k.upper(), k.lower(), k.title(), k.replace('World', 'Universe'),
# k.isalnum(), k.isalpha(), k.isdecimal(), k.isdigit(), k.isidentifier(), k.isnumeric(), k.isprintable(), k.isspace(), k.isupper(), k.islower(),
# k.startswith(' Hello'), k.endswith('World '), k.find('World'), k.rfind('World'), k.index('World'), k.rindex('World'), k.count('World'),
# k.split(), k.split(' '), k.split(' ', 1),
# k.center(20), k.ljust(20), k.rjust(20),
# k.partition('Hello'), k.rpartition('World').
# k.zfill(20)

# %%
age = '21'
txt = "My name is Rudra, My age is " + age
print(txt)

# %%
txt = "My name is Rudra, My age is {} "
print(txt.format(age))
print(f"My name is Rudra, My age is {age}")

# %%
pow(2,3)

# %%
L1 = [23,34,54,'ABC']
L1

# %%
L1[3:7]
